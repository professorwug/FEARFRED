# %% [raw]
# ---
# output-file: visualization_utils.html
# title: Visualization functions
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Plotting a 2D flow field

# %%
#|output: asis
#| echo: false
show_doc(plot_directed_2d)
# Out:
# ---
#
# [source](https://github.com/professorwug/FEARFRED/blob/main/FEARFRED/plotting.py#L10){target="_blank" style="float:right; font-size:smaller"}
#
# ### plot_directed_2d
#
# >      plot_directed_2d (X, flows, labels=None, mask_prob=0.5, cmap='viridis',
# >                        ax=None, save=False, use_streamlines=True, title='',
# >                        filename='', equal_aspect_ratio=True, minimal=False,
# >                        arrow_scale=8)

# %%
#|output: asis
#| echo: false
show_doc(plot_flow_field_2d)
# Out:
# ---
#
# [source](https://github.com/professorwug/FEARFRED/blob/main/FEARFRED/plotting.py#L47){target="_blank" style="float:right; font-size:smaller"}
#
# ### plot_flow_field_2d
#
# >      plot_flow_field_2d (FG, n_samples=500, arrow_scale=8)
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | FG |  |  | An instance of the FlowGenerator class |
# | n_samples | int | 500 |  |
# | arrow_scale | int | 8 | size of the arrows in the embedding. A smaller number creates larger arrows. |

# %% [markdown]
# # Plotting 3d Manifolds

# %%
#|output: asis
#| echo: false
show_doc(plot_directed_3d)
# Out:
# ---
#
# [source](https://github.com/professorwug/FEARFRED/blob/main/FEARFRED/plotting.py#L65){target="_blank" style="float:right; font-size:smaller"}
#
# ### plot_directed_3d
#
# >      plot_directed_3d (X, flow, labels=None, mask_prob=0.5, cmap='viridis',
# >                        origin=False, ax=None, save=False, filename='',
# >                        plot_minimal=False)

# %%
#|output: asis
#| echo: false
show_doc(plot_origin_3d)
# Out:
# ---
#
# [source](https://github.com/professorwug/FEARFRED/blob/main/FEARFRED/plotting.py#L59){target="_blank" style="float:right; font-size:smaller"}
#
# ### plot_origin_3d
#
# >      plot_origin_3d (ax, xlim, ylim, zlim)

# %% [markdown]
# # Plotting Graphs

# %%
#|output: asis
#| echo: false
show_doc(visualize_graph)
# Out:
# ---
#
# [source](https://github.com/professorwug/FEARFRED/blob/main/FEARFRED/plotting.py#L109){target="_blank" style="float:right; font-size:smaller"}
#
# ### visualize_graph
#
# >      visualize_graph (adjacency, is_networkx=False, to_undirected=False,
# >                       ax=None)
